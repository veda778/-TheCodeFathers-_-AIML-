# %%
pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in c:\users\veda\anaconda3\lib\site-packages (2.32.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\veda\anaconda3\lib\site-packages (4.12.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\veda\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\veda\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\veda\anaconda3\lib\site-packages (from requests) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\veda\anaconda3\lib\site-packages (from requests) (2024.8.30)
# Requirement already satisfied: soupsieve>1.2 in c:\users\veda\anaconda3\lib\site-packages (from beautifulsoup4) (2.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup
import json

# Sample URLs and API keys for different job platforms
API_KEYS = {
    'example_platform': 'YOUR_API_KEY_HERE'
}

JOB_SOURCES = {
    "naukri_API": "https://www.naukri.com/",
    "Cutshort_Scraping": "https://cutshort.io/profile/recommended-jobs"
}


def collect_job_data_from_api(url, headers=None, params=None):
    """Fetch job data using an API."""
    try:
        response = requests.get(url, headers=headers, params=params)
        response.raise_for_status()
        data = response.json()
        print("Data collected from API successfully!")
        return data  # Return JSON data from API response
    except requests.exceptions.RequestException as e:
        print(f"API request failed: {e}")
        return None


def collect_job_data_from_web(url):
    """Scrape job data from a web page."""
    try:
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Example scraping logic: Adapt selectors based on the website's structure
        jobs = []
        for job_card in soup.select('.result'):
            title = job_card.select_one('.title').text.strip()
            company = job_card.select_one('.company').text.strip()
            location = job_card.select_one('.location').text.strip()
            description = job_card.select_one('.summary').text.strip()
            
            jobs.append({
                'title': title,
                'company': company,
                'location': location,
                'description': description
            })
        print("Data collected from web scraping successfully!")
        return jobs
    except requests.exceptions.RequestException as e:
        print(f"Web scraping request failed: {e}")
        return None


# Example for LinkedIn API (replace headers and parameters with actual API requirements)
def fetch_jobs_from_naukri():
    url = JOB_SOURCES["naukri_API"]
    headers = {
        "Authorization": f"Bearer {API_KEYS['example_platform']}"
    }
    params = {
        "keywords": "software developer",
        "location": "Remote"
    }
    return collect_job_data_from_api(url, headers=headers, params=params)


# Example for Indeed scraping
def fetch_jobs_from_cutshort():
    url = JOB_SOURCES["Cutshort_Scraping"]
    return collect_job_data_from_web(url)


# Collecting data from both sources
def main():
    # Fetch data from LinkedIn API
    naukri_jobs = fetch_jobs_from_naukri()
    if naukri_jobs:
        print(json.dumps(naukri_jobs, indent=2))

    # Fetch data from Indeed using scraping
    cutshort_jobs = fetch_jobs_from_cutshort()
    if cutshort_jobs:
        print(json.dumps(cutshort_jobs, indent=2))


if __name__ == "__main__":
    main()
# Out:
# API request failed: Expecting value: line 1 column 1 (char 0)
# Data collected from web scraping successfully!

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\veda\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\veda\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\veda\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\veda\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\veda\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\veda\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install spacy
# Out:
# Collecting spacy
#   Downloading spacy-3.8.2-cp312-cp312-win_amd64.whl.metadata (27 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Downloading murmurhash-1.0.10-cp312-cp312-win_amd64.whl.metadata (2.0 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Downloading cymem-2.0.8-cp312-cp312-win_amd64.whl.metadata (8.6 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Downloading preshed-3.0.9-cp312-cp312-win_amd64.whl.metadata (2.2 kB)
# Collecting thinc<8.4.0,>=8.3.0 (from spacy)
#   Downloading thinc-8.3.2-cp312-cp312-win_amd64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Downloading wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy)
#   Downloading srsly-2.4.8-cp312-cp312-win_amd64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.5.0,>=0.1.0 (from spacy)
#   Downloading weasel-0.4.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting typer<1.0.0,>=0.3.0 (from spacy)
#   Downloading typer-0.13.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\veda\anaconda3\lib\site-packages (from spacy) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\veda\anaconda3\lib\site-packages (from spacy) (2.32.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\veda\anaconda3\lib\site-packages (from spacy) (2.9.2)
# Requirement already satisfied: jinja2 in c:\users\veda\anaconda3\lib\site-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\veda\anaconda3\lib\site-packages (from spacy) (69.5.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\veda\anaconda3\lib\site-packages (from spacy) (23.2)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy)
#   Downloading langcodes-3.4.1-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\veda\anaconda3\lib\site-packages (from spacy) (1.26.4)
# Collecting language-data>=1.2 (from langcodes<4.0.0,>=3.2.0->spacy)
#   Downloading language_data-1.2.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\veda\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\veda\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\veda\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\veda\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\veda\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\veda\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\veda\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.8.30)
# Collecting blis<1.1.0,>=1.0.0 (from thinc<8.4.0,>=8.3.0->spacy)
#   Downloading blis-1.0.1-cp312-cp312-win_amd64.whl.metadata (7.8 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.4.0,>=8.3.0->spacy)
#   Downloading confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# Collecting numpy>=1.19.0 (from spacy)
#   Downloading numpy-2.0.2-cp312-cp312-win_amd64.whl.metadata (59 kB)
#      ---------------------------------------- 0.0/59.7 kB ? eta -:--:--
#      ---------------------------------------- 59.7/59.7 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\veda\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\veda\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Collecting shellingham>=1.3.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: rich>=10.11.0 in c:\users\veda\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.3.5)
# Collecting cloudpathlib<1.0.0,>=0.7.0 (from weasel<0.5.0,>=0.1.0->spacy)
#   Downloading cloudpathlib-0.20.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\veda\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\veda\anaconda3\lib\site-packages (from jinja2->spacy) (2.1.3)
# Collecting marisa-trie>=0.7.7 (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy)
#   Downloading marisa_trie-1.2.1-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\veda\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\veda\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\veda\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.0)
# Downloading spacy-3.8.2-cp312-cp312-win_amd64.whl (11.8 MB)
#    ---------------------------------------- 0.0/11.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.7/11.8 MB 15.7 MB/s eta 0:00:01
#    -------- ------------------------------- 2.5/11.8 MB 22.9 MB/s eta 0:00:01
#    ------------ --------------------------- 3.6/11.8 MB 25.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.1/11.8 MB 27.1 MB/s eta 0:00:01
#    ------------------ --------------------- 5.6/11.8 MB 25.4 MB/s eta 0:00:01
#    ------------------- -------------------- 5.7/11.8 MB 19.2 MB/s eta 0:00:01
#    ------------------------ --------------- 7.2/11.8 MB 21.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.3/11.8 MB 21.1 MB/s eta 0:00:01
#    ------------------------------- -------- 9.3/11.8 MB 22.0 MB/s eta 0:00:01
#    -------------------------------- ------- 9.6/11.8 MB 21.2 MB/s eta 0:00:01
#    -------------------------------------- - 11.3/11.8 MB 21.9 MB/s eta 0:00:01
#    ---------------------------------------  11.8/11.8 MB 20.5 MB/s eta 0:00:01
#    ---------------------------------------- 11.8/11.8 MB 19.2 MB/s eta 0:00:00
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading cymem-2.0.8-cp312-cp312-win_amd64.whl (39 kB)
# Downloading langcodes-3.4.1-py3-none-any.whl (182 kB)
#    ---------------------------------------- 0.0/182.4 kB ? eta -:--:--
#    --------------------------------------- 182.4/182.4 kB 10.8 MB/s eta 0:00:00
# Downloading murmurhash-1.0.10-cp312-cp312-win_amd64.whl (25 kB)
# Downloading preshed-3.0.9-cp312-cp312-win_amd64.whl (122 kB)
#    ---------------------------------------- 0.0/122.4 kB ? eta -:--:--
#    ---------------------------------------- 122.4/122.4 kB 7.0 MB/s eta 0:00:00
# Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.4.8-cp312-cp312-win_amd64.whl (478 kB)
#    ---------------------------------------- 0.0/478.8 kB ? eta -:--:--
#    ------------------------------ -------- 378.9/478.8 kB 24.6 MB/s eta 0:00:01
#    ---------------------------------------- 478.8/478.8 kB 5.0 MB/s eta 0:00:00
# Downloading thinc-8.3.2-cp312-cp312-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    -------------- ------------------------- 0.5/1.5 MB 33.5 MB/s eta 0:00:01
#    -------------------- ------------------- 0.7/1.5 MB 15.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 11.6 MB/s eta 0:00:00
# Downloading numpy-2.0.2-cp312-cp312-win_amd64.whl (15.6 MB)
#    ---------------------------------------- 0.0/15.6 MB ? eta -:--:--
#    - -------------------------------------- 0.4/15.6 MB 13.9 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.6/15.6 MB 20.3 MB/s eta 0:00:01
#    ------ --------------------------------- 2.7/15.6 MB 21.1 MB/s eta 0:00:01
#    ---------- ----------------------------- 4.2/15.6 MB 24.3 MB/s eta 0:00:01
#    -------------- ------------------------- 5.5/15.6 MB 25.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 6.7/15.6 MB 25.2 MB/s eta 0:00:01
#    --------------------- ------------------ 8.5/15.6 MB 27.3 MB/s eta 0:00:01
#    ------------------------ --------------- 9.6/15.6 MB 26.7 MB/s eta 0:00:01
#    --------------------------- ------------ 10.8/15.6 MB 28.5 MB/s eta 0:00:01
#    ------------------------------ --------- 11.8/15.6 MB 27.3 MB/s eta 0:00:01
#    -------------------------------- ------- 12.5/15.6 MB 27.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.6/15.6 MB 26.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 14.0/15.6 MB 24.3 MB/s eta 0:00:01
#    -------------------------------------- - 15.1/15.6 MB 21.8 MB/s eta 0:00:01
#    ---------------------------------------- 15.6/15.6 MB 21.8 MB/s eta 0:00:00
# Downloading typer-0.13.0-py3-none-any.whl (44 kB)
#    ---------------------------------------- 0.0/44.2 kB ? eta -:--:--
#    ---------------------------------------- 44.2/44.2 kB ? eta 0:00:00
# Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Downloading weasel-0.4.1-py3-none-any.whl (50 kB)
#    ---------------------------------------- 0.0/50.3 kB ? eta -:--:--
#    ---------------------------------------- 50.3/50.3 kB ? eta 0:00:00
# Downloading blis-1.0.1-cp312-cp312-win_amd64.whl (6.4 MB)
#    ---------------------------------------- 0.0/6.4 MB ? eta -:--:--
#    ------ --------------------------------- 1.0/6.4 MB 32.7 MB/s eta 0:00:01
#    ----------- ---------------------------- 1.8/6.4 MB 22.8 MB/s eta 0:00:01
#    -------------- ------------------------- 2.3/6.4 MB 20.9 MB/s eta 0:00:01
#    --------------------- ------------------ 3.5/6.4 MB 20.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 4.7/6.4 MB 23.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 5.6/6.4 MB 22.5 MB/s eta 0:00:01
#    ---------------------------------------  6.3/6.4 MB 21.2 MB/s eta 0:00:01
#    ---------------------------------------- 6.4/6.4 MB 19.4 MB/s eta 0:00:00
# Downloading cloudpathlib-0.20.0-py3-none-any.whl (52 kB)
#    ---------------------------------------- 0.0/52.5 kB ? eta -:--:--
#    ---------------------------------------- 52.5/52.5 kB 2.6 MB/s eta 0:00:00
# Downloading confection-0.1.5-py3-none-any.whl (35 kB)
# Downloading language_data-1.2.0-py3-none-any.whl (5.4 MB)
#    ---------------------------------------- 0.0/5.4 MB ? eta -:--:--
#    -------- ------------------------------- 1.1/5.4 MB 34.9 MB/s eta 0:00:01
#    ------------ --------------------------- 1.7/5.4 MB 27.1 MB/s eta 0:00:01
#    --------------------- ------------------ 2.9/5.4 MB 25.9 MB/s eta 0:00:01
#    -------------------------- ------------- 3.5/5.4 MB 24.8 MB/s eta 0:00:01
#    ---------------------------------------  5.4/5.4 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------- 5.4/5.4 MB 22.9 MB/s eta 0:00:00
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading marisa_trie-1.2.1-cp312-cp312-win_amd64.whl (150 kB)
#    ---------------------------------------- 0.0/150.8 kB ? eta -:--:--
#    ---------------------------------------- 150.8/150.8 kB ? eta 0:00:00
# Installing collected packages: cymem, wasabi, spacy-loggers, spacy-legacy, shellingham, numpy, murmurhash, marisa-trie, cloudpathlib, catalogue, srsly, preshed, language-data, blis, typer, langcodes, confection, weasel, thinc, spacy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# Successfully installed blis-1.0.1 catalogue-2.0.10 cloudpathlib-0.20.0 confection-0.1.5 cymem-2.0.8 langcodes-3.4.1 language-data-1.2.0 marisa-trie-1.2.1 murmurhash-1.0.10 numpy-2.0.2 preshed-3.0.9 shellingham-1.5.4 spacy-3.8.2 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.4.8 thinc-8.3.2 typer-0.13.0 wasabi-1.1.3 weasel-0.4.1
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Veda\anaconda3\Lib\site-packages\~umpy'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# contourpy 1.2.0 requires numpy<2.0,>=1.20, but you have numpy 2.0.2 which is incompatible.
# langchain 0.3.4 requires numpy<2.0.0,>=1.26.0; python_version >= "3.12", but you have numpy 2.0.2 which is incompatible.
# langchain-community 0.3.3 requires numpy<2.0.0,>=1.26.0; python_version >= "3.12", but you have numpy 2.0.2 which is incompatible.
# numba 0.59.1 requires numpy<1.27,>=1.22, but you have numpy 2.0.2 which is incompatible.
# pywavelets 1.5.0 requires numpy<2.0,>=1.22.4, but you have numpy 2.0.2 which is incompatible.
# streamlit 1.32.0 requires numpy<2,>=1.19.3, but you have numpy 2.0.2 which is incompatible.

# %%
pip install PyMuPDF python-docx spacy
# Out:
# Collecting PyMuPDF
#   Downloading PyMuPDF-1.24.13-cp39-abi3-win_amd64.whl.metadata (3.4 kB)
# Collecting python-docx
#   Downloading python_docx-1.1.2-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: spacy in c:\users\veda\anaconda3\lib\site-packages (3.8.2)
# Requirement already satisfied: lxml>=3.1.0 in c:\users\veda\anaconda3\lib\site-packages (from python-docx) (5.2.1)
# Requirement already satisfied: typing-extensions>=4.9.0 in c:\users\veda\anaconda3\lib\site-packages (from python-docx) (4.11.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\veda\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\veda\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\veda\anaconda3\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\veda\anaconda3\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\veda\anaconda3\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.0 in c:\users\veda\anaconda3\lib\site-packages (from spacy) (8.3.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\veda\anaconda3\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\veda\anaconda3\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\veda\anaconda3\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\veda\anaconda3\lib\site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\veda\anaconda3\lib\site-packages (from spacy) (0.13.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\veda\anaconda3\lib\site-packages (from spacy) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\veda\anaconda3\lib\site-packages (from spacy) (2.32.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\veda\anaconda3\lib\site-packages (from spacy) (2.9.2)
# Requirement already satisfied: jinja2 in c:\users\veda\anaconda3\lib\site-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\veda\anaconda3\lib\site-packages (from spacy) (69.5.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\veda\anaconda3\lib\site-packages (from spacy) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\veda\anaconda3\lib\site-packages (from spacy) (3.4.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\veda\anaconda3\lib\site-packages (from spacy) (2.0.2)
# Requirement already satisfied: language-data>=1.2 in c:\users\veda\anaconda3\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\veda\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\veda\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\veda\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\veda\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\veda\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\veda\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.8.30)
# Requirement already satisfied: blis<1.1.0,>=1.0.0 in c:\users\veda\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.0->spacy) (1.0.1)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\veda\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.0->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\veda\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\veda\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\veda\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\veda\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.3.5)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\veda\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\veda\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\veda\anaconda3\lib\site-packages (from jinja2->spacy) (2.1.3)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\veda\anaconda3\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\veda\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\veda\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\veda\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.0)
# Downloading PyMuPDF-1.24.13-cp39-abi3-win_amd64.whl (16.2 MB)
#    ---------------------------------------- 0.0/16.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.2 MB 330.3 kB/s eta 0:00:50
#    ---------------------------------------- 0.2/16.2 MB 1.4 MB/s eta 0:00:12
#    -- ------------------------------------- 0.8/16.2 MB 6.0 MB/s eta 0:00:03
#    --- ------------------------------------ 1.4/16.2 MB 6.7 MB/s eta 0:00:03
#    ---- ----------------------------------- 2.0/16.2 MB 8.1 MB/s eta 0:00:02
#    ------ --------------------------------- 2.8/16.2 MB 9.5 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.4/16.2 MB 12.7 MB/s eta 0:00:01
#    ------------- -------------------------- 5.5/16.2 MB 14.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 7.0/16.2 MB 16.0 MB/s eta 0:00:01
#    ------------------ --------------------- 7.6/16.2 MB 15.8 MB/s eta 0:00:01
#    -------------------- ------------------- 8.3/16.2 MB 15.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 9.3/16.2 MB 16.1 MB/s eta 0:00:01
#    ------------------------- -------------- 10.5/16.2 MB 20.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 11.6/16.2 MB 21.1 MB/s eta 0:00:01
#    -------------------------------- ------- 13.0/16.2 MB 23.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 14.1/16.2 MB 22.6 MB/s eta 0:00:01
#    ------------------------------------- -- 15.3/16.2 MB 22.6 MB/s eta 0:00:01
#    ---------------------------------------  16.1/16.2 MB 22.6 MB/s eta 0:00:01
#    ---------------------------------------  16.2/16.2 MB 21.8 MB/s eta 0:00:01
#    ---------------------------------------- 16.2/16.2 MB 19.8 MB/s eta 0:00:00
# Downloading python_docx-1.1.2-py3-none-any.whl (244 kB)
#    ---------------------------------------- 0.0/244.3 kB ? eta -:--:--
#    ---------------------------------------- 244.3/244.3 kB 7.6 MB/s eta 0:00:00
# Installing collected packages: python-docx, PyMuPDF
# Successfully installed PyMuPDF-1.24.13 python-docx-1.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install PyMuPDF python-docx spacy
# Out:
# Requirement already satisfied: PyMuPDF in c:\users\veda\anaconda3\lib\site-packages (1.24.13)
# Requirement already satisfied: python-docx in c:\users\veda\anaconda3\lib\site-packages (1.1.2)
# Requirement already satisfied: spacy in c:\users\veda\anaconda3\lib\site-packages (3.8.2)
# Requirement already satisfied: lxml>=3.1.0 in c:\users\veda\anaconda3\lib\site-packages (from python-docx) (5.2.1)
# Requirement already satisfied: typing-extensions>=4.9.0 in c:\users\veda\anaconda3\lib\site-packages (from python-docx) (4.11.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\veda\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\veda\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\veda\anaconda3\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\veda\anaconda3\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\veda\anaconda3\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.0 in c:\users\veda\anaconda3\lib\site-packages (from spacy) (8.3.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\veda\anaconda3\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\veda\anaconda3\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\veda\anaconda3\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\veda\anaconda3\lib\site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\veda\anaconda3\lib\site-packages (from spacy) (0.13.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\veda\anaconda3\lib\site-packages (from spacy) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\veda\anaconda3\lib\site-packages (from spacy) (2.32.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\veda\anaconda3\lib\site-packages (from spacy) (2.9.2)
# Requirement already satisfied: jinja2 in c:\users\veda\anaconda3\lib\site-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\veda\anaconda3\lib\site-packages (from spacy) (69.5.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\veda\anaconda3\lib\site-packages (from spacy) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\veda\anaconda3\lib\site-packages (from spacy) (3.4.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\veda\anaconda3\lib\site-packages (from spacy) (2.0.2)
# Requirement already satisfied: language-data>=1.2 in c:\users\veda\anaconda3\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\veda\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\veda\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\veda\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\veda\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\veda\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\veda\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.8.30)
# Requirement already satisfied: blis<1.1.0,>=1.0.0 in c:\users\veda\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.0->spacy) (1.0.1)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\veda\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.0->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\veda\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\veda\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\veda\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\veda\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.3.5)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\veda\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\veda\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\veda\anaconda3\lib\site-packages (from jinja2->spacy) (2.1.3)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\veda\anaconda3\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\veda\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\veda\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\veda\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup
import json

# Sample URLs and API keys for different job platforms
API_KEYS = {
    'example_platform': 'YOUR_API_KEY_HERE'
}

JOB_SOURCES = {
    "naukri_API": "https://www.naukri.com/",
    "Cutshort_Scraping": "https://cutshort.io/profile/recommended-jobs"
}


def collect_job_data_from_api(url, headers=None, params=None):
    """Fetch job data using an API."""
    try:
        response = requests.get(url, headers=headers, params=params)
        response.raise_for_status()
        data = response.json()
        print("Data collected from API successfully!")
        return data  # Return JSON data from API response
    except requests.exceptions.RequestException as e:
        print(f"API request failed: {e}")
        return None


def collect_job_data_from_web(url):
    """Scrape job data from a web page."""
    try:
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Example scraping logic: Adapt selectors based on the website's structure
        jobs = []
        for job_card in soup.select('.result'):
            title = job_card.select_one('.title').text.strip()
            company = job_card.select_one('.company').text.strip()
            location = job_card.select_one('.location').text.strip()
            description = job_card.select_one('.summary').text.strip()
            
            jobs.append({
                'title': title,
                'company': company,
                'location': location,
                'description': description
            })
        print("Data collected from web scraping successfully!")
        return jobs
    except requests.exceptions.RequestException as e:
        print(f"Web scraping request failed: {e}")
        return None


# Example for LinkedIn API (replace headers and parameters with actual API requirements)
def fetch_jobs_from_naukri():
    url = JOB_SOURCES["naukri_API"]
    headers = {
        "Authorization": f"Bearer {API_KEYS['example_platform']}"
    }
    params = {
        "keywords": "software developer",
        "location": "Remote"
    }
    return collect_job_data_from_api(url, headers=headers, params=params)


# Example for Indeed scraping
def fetch_jobs_from_cutshort():
    url = JOB_SOURCES["Cutshort_Scraping"]
    return collect_job_data_from_web(url)


# Collecting data from both sources
def main():
    # Fetch data from LinkedIn API
    naukri_jobs = fetch_jobs_from_naukri()
    if naukri_jobs:
        print(json.dumps(naukri_jobs, indent=2))

    # Fetch data from Indeed using scraping
    cutshort_jobs = fetch_jobs_from_cutshort()
    if cutshort_jobs:
        print(json.dumps(cutshort_jobs, indent=2))


if __name__ == "__main__":
    main()
# Out:
# API request failed: Expecting value: line 1 column 1 (char 0)
# Data collected from web scraping successfully!
